# %% [markdown]
# # "머신러닝을 통한 접근 가이드" 목차
# ## 1. Library
# ## 2. Data Loading
# ## 3. Feature Engineering
# ### 3-1. Feature Generation
# #### CODE SHARE WITH "파베르"님
# #### (https://dacon.io/competitions/official/235745/codeshare/2851?page=1&dtype=recent)
# ### 3-2. Feature Engineering
# #### 3-2-1. Encoding
# #### 3-2-2. Scailing
# ## 4. Modeling with Pycaret
# ## 5. Modeling with CatBoostRegressor

# %% [markdown]
# ## 1. Library

# %%
# for "2. Data Loading"
import pandas as pd

# for "3-1. Feature Generation"
import numpy as np

# for "3-2. Feature Engineering"
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import RobustScaler, StandardScaler

# for "4. Modeling with Pycaret"
from pycaret.regression import *

# for "5. Modeling with CatBoostRegressor"
from catboost import CatBoostRegressor
import optuna
from optuna import Trial
from optuna.samplers import TPESampler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split, StratifiedKFold

# %% [markdown]
# ## 2. Data Loading

# %%
train = pd.read_csv('data/train0723(5).3.csv')
test = pd.read_csv('data/test0723.fi.csv')
train = train.set_index("code")
test = test.set_index("code")

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# ### 3-1. Feature Generation
# #### CODE SHARE WITH "파베르"님
# #### (https://dacon.io/competitions/official/235745/codeshare/2851?page=1&dtype=recent)
# ##### Feature Generation과 관련된 EDA는 위의 링크를 참조해주세요 :)

# %%
train.loc[train.임대보증금=='-', '임대보증금'] = np.nan
test.loc[test.임대보증금=='-', '임대보증금'] = np.nan
train['임대보증금'] = train['임대보증금'].astype(float)
test['임대보증금'] = test['임대보증금'].astype(float)

train.loc[train.임대료=='-', '임대료'] = np.nan
test.loc[test.임대료=='-', '임대료'] = np.nan
train['임대료'] = train['임대료'].astype(float)
test['임대료'] = test['임대료'].astype(float)

train[['임대보증금', '임대료']] = train[['임대보증금', '임대료']].fillna(0)
test[['임대보증금', '임대료']] = test[['임대보증금', '임대료']].fillna(0)

cols = ['도보 10분거리 내 지하철역 수(환승노선 수 반영)', '도보 10분거리 내 버스정류장 수']
train[cols] = train[cols].fillna(0)
test[cols] = test[cols].fillna(0)

#### (3) 자격유형

test.loc[test.단지코드.isin(['C2411']) & test.자격유형.isnull(), '자격유형'] = 'A'
test.loc[test.단지코드.isin(['C2253']) & test.자격유형.isnull(), '자격유형'] = 'C'

train = train.drop_duplicates()
test = test.drop_duplicates()

unique_cols = ['총세대수', '지역', '공가수', 
               '도보 10분거리 내 지하철역 수(환승노선 수 반영)',
               '도보 10분거리 내 버스정류장 수',
               '단지내주차면수', '등록차량수']
train_agg = train.set_index('단지코드')[unique_cols].drop_duplicates()
test_agg = test.set_index('단지코드')[[col for col in unique_cols if col!='등록차량수']].drop_duplicates()

def reshape_cat_features(data, cast_col, value_col):
    res = data.drop_duplicates(['단지코드', cast_col]).assign(counter=1).pivot(index='단지코드', columns=cast_col, values=value_col).fillna(0)
    res.columns.name = None
    res = res.rename(columns={col:cast_col+'_'+col for col in res.columns})
    return res

train.loc[train.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'
test.loc[test.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'
train.loc[train.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'
test.loc[test.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'

train.loc[train.자격유형.isin(['J', 'L', 'K', 'N', 'M', 'O']), '자격유형'] = '행복주택_공급대상'
test.loc[test.자격유형.isin(['J', 'L', 'K', 'N', 'M', 'O']), '자격유형'] = '행복주택_공급대상'

train.loc[train.자격유형.isin(['H', 'B', 'E', 'G']), '자격유형'] = '국민임대/장기전세_공급대상'
test.loc[test.자격유형.isin(['H', 'B', 'E', 'G']), '자격유형'] = '국민임대/장기전세_공급대상'

train.loc[train.자격유형.isin(['C', 'I', 'F']), '자격유형'] = '영구임대_공급대상'
test.loc[test.자격유형.isin(['C', 'I', 'F']), '자격유형'] = '영구임대_공급대상'

X_train = pd.concat([train_agg,
                       reshape_cat_features(data=train, cast_col='임대건물구분', value_col='counter'),
                       reshape_cat_features(data=train, cast_col='공급유형', value_col='counter'),
                       reshape_cat_features(data=train, cast_col='자격유형', value_col='counter')], axis=1)

X_test = pd.concat([test_agg,
                       reshape_cat_features(data=test, cast_col='임대건물구분', value_col='counter'),
                       reshape_cat_features(data=test, cast_col='공급유형', value_col='counter'),
                       reshape_cat_features(data=test, cast_col='자격유형', value_col='counter')], axis=1)

# %% [markdown]
# ### 3-2. Feature Engineering
# - 필요성?

# %%
X_train.head(3)

# 1. 지역은 글자데이터이다.
## 한글은 Catboost 이외에는 받아들일 수 없기  때문에, Encoding 과정이 필요하다.
## 해결법  : 통계치를 반영한 Encoding과, One-Hot Encoding 모두 적용해준다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-35fbff1e90b8> in <module>
# ----> 1 X_train.head(3)
#       2
#       3 # 1. 지역은 글자데이터이다.
#       4 ## 한글은 Catboost 이외에는 받아들일 수 없기  때문에, Encoding 과정이 필요하다.
#       5 ## 해결법  : 통계치를 반영한 Encoding과, One-Hot Encoding 모두 적용해준다.
#
# NameError: name 'X_train' is not defined

# %%
X_train.describe()

# 2. 단위가 다르다.
## 총 세대수, 공가수는 "세대 수"를, "도보 ~~"는 근처의 "개수"를, "단지내주차면수"는 "면적"을 의미하는 등 의미하는 바가 다르다.
## 이 경우에는, Feature의 "Scale"을 동일하게 해주지 않으면 Machine Learning과정에서 가중치 학습에 있어서 오류가 있을 수 있다.
## 해결법 : Robust Scailing을 적용해준다. (Good for outliers)

# 3. 이상치가 보인다.
## "도보 10분 거리 내 버스정류장 수"를 확인하면, 75%까지는 4이나, max는 20인 것을 확인할 수 있다.
## "도보 10분 거리 내 지하철역~`"은 75%까지는 0이지만, max는 3인 것을 확인할 수 있다.
## 이상치는 Linear Regression Model에서 상대적으로 큰 영향력을 끼친다.
## 해결법 : 데이터를 살펴보고, 처리를 결정한다.

# 4. 의미 없는 Feature도 확인되었다.
## "임대건물구분_아파트"의 경우 모두가 1이다.
## 해결법 : 단순 제거해준다.
# Out:
#               총세대수         공가수  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# count   423.000000  423.000000                    423.000000
# mean    722.387707   13.479905                      0.120567
# std     405.590274   10.385414                      0.379733
# min      26.000000    0.000000                      0.000000
# 25%     447.500000    5.000000                      0.000000
# 50%     632.000000   13.000000                      0.000000
# 75%     923.000000   20.000000                      0.000000
# max    2568.000000   55.000000                      3.000000
#
#        도보 10분거리 내 버스정류장 수      단지내주차면수        등록차량수   임대건물구분_상가  임대건물구분_아파트  \
# count          423.000000   423.000000   423.000000  423.000000       423.0
# mean             3.690307   592.744681   572.335697    0.078014         1.0
# std              2.808429   367.655143   391.032563    0.268511         0.0
# min              0.000000    13.000000    13.000000    0.000000         1.0
# 25%              2.000000   319.500000   295.000000    0.000000         1.0
# 50%              3.000000   523.000000   505.000000    0.000000         1.0
# 75%              4.000000   803.000000   762.500000    0.000000         1.0
# max             20.000000  1798.000000  2550.000000    1.000000         1.0
#
#        공급유형_공공임대(50년)  공급유형_공공임대(5년/10년/분납/분양)  공급유형_국민임대/장기전세   공급유형_영구임대  \
# count      423.000000               423.000000      423.000000  423.000000
# mean         0.026005                 0.089835        0.742317    0.132388
# std          0.159338                 0.286283        0.437877    0.339313
# min          0.000000                 0.000000        0.000000    0.000000
# 25%          0.000000                 0.000000        0.000000    0.000000
# 50%          0.000000                 0.000000        1.000000    0.000000
# 75%          0.000000                 0.000000        1.000000    0.000000
# max          1.000000                 1.000000        1.000000    1.000000
#
#         공급유형_임대상가   공급유형_행복주택      자격유형_A      자격유형_D  자격유형_국민임대/장기전세_공급대상  \
# count  423.000000  423.000000  423.000000  423.000000           423.000000
# mean     0.078014    0.073286    0.784870    0.080378             0.115839
# std      0.268511    0.260914    0.411399    0.272200             0.320411
# min      0.000000    0.000000    0.000000    0.000000             0.000000
# 25%      0.000000    0.000000    1.000000    0.000000             0.000000
# 50%      0.000000    0.000000    1.000000    0.000000             0.000000
# 75%      0.000000    0.000000    1.000000    0.000000             0.000000
# max      1.000000    1.000000    1.000000    1.000000             1.000000
#
#        자격유형_영구임대_공급대상  자격유형_행복주택_공급대상
# count      423.000000      423.000000
# mean         0.130024        0.073286
# std          0.336728        0.260914
# min          0.000000        0.000000
# 25%          0.000000        0.000000
# 50%          0.000000        0.000000
# 75%          0.000000        0.000000
# max          1.000000        1.000000

# %%
X_train = X_train.drop(columns = ['임대건물구분_아파트'])
X_test = X_test.drop(columns = ['임대건물구분_아파트'])

# %% [markdown]
# - 필요성 - 3. 이상치가 보인다

# %%
plt.boxplot([train['도보 10분거리 내 버스정류장 수']])
plt.show()

# 20에 가까운 값들이 존재하지만, 따로 처리해주기에는 독립적으로 떨어진 분포가 아니기 때문에, 제거하지 않는다.

# %%
display('Train Data')
display(X_train.groupby(['도보 10분거리 내 지하철역 수(환승노선 수 반영)'])['총세대수'].agg('count'))
display('='*50)
display('Test Data')
display(X_test.groupby(['도보 10분거리 내 지하철역 수(환승노선 수 반영)'])['총세대수'].agg('count'))
display('='*50)
# 지하철 역 수가 3인 데이터는 제거한다.

display('After Engineering')
X_train = X_train[X_train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'] != 3]
display(X_train.groupby(['도보 10분거리 내 지하철역 수(환승노선 수 반영)'])['총세대수'].agg('count'))
# Out:
# 'Train Data'
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)
# 0.0    379
# 1.0     38
# 2.0      5
# 3.0      1
# Name: 총세대수, dtype: int64
# '=================================================='
# 'Test Data'
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)
# 0.0    139
# 1.0      8
# 2.0      3
# Name: 총세대수, dtype: int64
# '=================================================='
# 'After Engineering'
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)
# 0.0    379
# 1.0     38
# 2.0      5
# Name: 총세대수, dtype: int64

# %% [markdown]
# #### 3-2-1. Encoding

# %%
# %%time
encoding_features = ['지역', '도보 10분거리 내 지하철역 수(환승노선 수 반영)']
for f in encoding_features:
    mapping = X_train.groupby([f])['등록차량수'].agg(['mean','median','std'])
    mapping_values = []
    for l in X_train[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_train.index)
    X_train = pd.concat([X_train,bincount], axis= 1).drop(columns = [f])

    mapping_values = []
    for l in X_test[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_test.index)
    X_test = pd.concat([X_test,bincount], axis= 1).drop(columns = [f])
# Out:
# CPU times: user 86.5 ms, sys: 761 µs, total: 87.3 ms
# Wall time: 92.6 ms

# %% [markdown]
# #### 3-2-2. Scailing

# %%
scailing_features = ['총세대수',
                     '공가수',
                     '도보 10분거리 내 버스정류장 수',
                     '단지내주차면수',
                     '지역_mean', 
                     '지역_median',
                     '지역_std', 
                     '도보 10분거리 내 지하철역 수(환승노선 수 반영)_mean',
                   '도보 10분거리 내 지하철역 수(환승노선 수 반영)_median',
                   '도보 10분거리 내 지하철역 수(환승노선 수 반영)_std'
                    ]

# %%
fig, axes = plt.subplots(2,5, figsize= (12,12))

i = 0
for f in scailing_features:
    c = i % 5
    r = i // 5
    
    axes[r,c].hist(x = f, bins =50, data = X_train)
    i += 1
plt.show()


# 지역은 이상치가 확인 => Robust Scailing
# 도보 -> std 제거
# 나머지는 Standard

# %%
# 도보 10분거리 std는 그림상 의미가 없기에 Drop
X_train = X_train.iloc[:,:-1]
X_test = X_test.iloc[:,:-1]

# %%
# 지역은  Scailing

scaler = RobustScaler()
loc_f = [    '지역_mean', 
             '지역_median',
             '지역_std', ]
X_train.loc[:, loc_f] = scaler.fit_transform(X_train[loc_f])
X_test.loc[:, loc_f] = scaler.transform(X_test[loc_f])

# %%
# 나머지 Scailing
scailing_features = ['총세대수',
                     '공가수',
                     '도보 10분거리 내 버스정류장 수',
                     '단지내주차면수',
                     '도보 10분거리 내 지하철역 수(환승노선 수 반영)_mean',
                       '도보 10분거리 내 지하철역 수(환승노선 수 반영)_median',
                    ]

scaler = StandardScaler()
X_train.loc[:, scailing_features] = scaler.fit_transform(X_train[scailing_features])
X_test.loc[:, scailing_features] = scaler.transform(X_test[scailing_features])

# %% [markdown]
# ## 4. Modeling with pycaret

# %%
reg = setup(train, 
            preprocess = False, # True로 설정되면, 자체적인 Feature Engineering을 추가로 진행해 Predict가 불가능해진다.
            train_size = 0.999,  # 우리는 전체 데이터를 학습해 test를 예측하는게 목표이기 때문에, 0.999로 설정한다.
            target = 'target', # 목표 변수는 등록 차량 수 이다.
            silent = True, # 엔터를 누르기 귀찮다. 궁금하면 풀어보세요
            use_gpu = False, # GPU가 있으면 사용하세요 (Cat BOost 속도 향상)
            numeric_features=list(train.drop(columns = ['target']).columns), # 모든 변수가 숫자로써의 의미가 있다.
            session_id = 2021,
            fold_shuffle = True
            )
# Out:
# <style  type="text/css" >
# </style><table id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow0_col1" class="data row0 col1" >2021</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow2_col1" class="data row2 col1" >(430, 41)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow4_col1" class="data row4 col1" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow6_col0" class="data row6 col0" >Transformed Train Set</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow6_col1" class="data row6 col1" >(429, 40)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow7_col0" class="data row7 col0" >Transformed Test Set</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow7_col1" class="data row7 col1" >(1, 40)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow8_col0" class="data row8 col0" >Shuffle Train-Test</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow9_col0" class="data row9 col0" >Stratify Train-Test</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow10_col0" class="data row10 col0" >Fold Generator</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow10_col1" class="data row10 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow11_col0" class="data row11 col0" >Fold Number</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow11_col1" class="data row11 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow12_col0" class="data row12 col0" >CPU Jobs</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow12_col1" class="data row12 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow13_col0" class="data row13 col0" >Use GPU</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow13_col1" class="data row13 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow14_col0" class="data row14 col0" >Log Experiment</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow15_col0" class="data row15 col0" >Experiment Name</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow15_col1" class="data row15 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow16_col0" class="data row16 col0" >USI</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow16_col1" class="data row16 col1" >18c9</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow17_col0" class="data row17 col0" >Transform Target</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow18_col0" class="data row18 col0" >Transform Target Method</td>
#                         <td id="T_cdff3a33_ed4d_11eb_aa4b_d8f8830f9b9arow18_col1" class="data row18 col1" >box-cox</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Top5의 모델 선택

# %%
top5 = compare_models(n_select = 5, sort = 'MAE')
# Out:
# <style  type="text/css" >
#     #T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9a th {
#           text-align: left;
#     }#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col4,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow12_col0,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow12_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow12_col2,#T_e4cb68 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col1,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col5,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col6,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col2,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col3,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow0_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow1_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow2_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow3_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow4_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow5_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow6_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow10_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow12_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow13_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow14_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow15_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow7_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow8_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow9_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow11_col7,#T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9arow17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_e4cb6873_ed4d_11eb_84cd_d8f8830f9b9a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RM

# %% [markdown]
# - Top5 Model Tuning

# %%
models = []
for m in top5:
    models.append(tune_model(m, 
                             optimize = 'MAE', 
                             choose_better = True,
                            n_iter = 30))
# Out:
# <style  type="text/css" >
# #T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col0,#T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col1,#T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col2,#T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col3,#T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col4,#T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow10_col5{
#             background:  yellow;
#         }</style><table id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col0" class="data row0 col0" >116.0656</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col1" class="data row0 col1" >31999.3613</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col2" class="data row0 col2" >178.8837</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col3" class="data row0 col3" >0.7183</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col4" class="data row0 col4" >0.3360</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow0_col5" class="data row0 col5" >0.2402</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col0" class="data row1 col0" >97.3072</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col1" class="data row1 col1" >21237.1816</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col2" class="data row1 col2" >145.7298</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col3" class="data row1 col3" >0.8320</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col4" class="data row1 col4" >0.3668</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow1_col5" class="data row1 col5" >0.2858</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col0" class="data row2 col0" >135.5821</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col1" class="data row2 col1" >42657.5039</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col2" class="data row2 col2" >206.5369</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col3" class="data row2 col3" >0.7180</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col4" class="data row2 col4" >0.3432</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow2_col5" class="data row2 col5" >0.2414</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col0" class="data row3 col0" >132.9229</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col1" class="data row3 col1" >38314.9648</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col2" class="data row3 col2" >195.7421</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col3" class="data row3 col3" >0.7348</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col4" class="data row3 col4" >0.5106</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow3_col5" class="data row3 col5" >0.5160</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col0" class="data row4 col0" >76.0930</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col1" class="data row4 col1" >10496.6416</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col2" class="data row4 col2" >102.4531</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col3" class="data row4 col3" >0.9042</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col4" class="data row4 col4" >0.3836</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow4_col5" class="data row4 col5" >0.3427</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col0" class="data row5 col0" >93.4018</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col1" class="data row5 col1" >16808.0488</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col2" class="data row5 col2" >129.6459</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col3" class="data row5 col3" >0.8424</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col4" class="data row5 col4" >0.3671</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow5_col5" class="data row5 col5" >0.3090</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col0" class="data row6 col0" >125.5893</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col1" class="data row6 col1" >41511.6250</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col2" class="data row6 col2" >203.7440</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col3" class="data row6 col3" >0.5926</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col4" class="data row6 col4" >0.2639</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow6_col5" class="data row6 col5" >0.2166</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col0" class="data row7 col0" >138.5362</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col1" class="data row7 col1" >46964.0156</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col2" class="data row7 col2" >216.7118</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col3" class="data row7 col3" >0.7828</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col4" class="data row7 col4" >0.2794</td>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow7_col5" class="data row7 col5" >0.2400</td>
#             </tr>
#             <tr>
#                         <th id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8714944a_ed4e_11eb_8582_d8f8830f9b9arow8_col0" class

# %%
voting = blend_models(models, optimize = 'MAE')
voting = tune_model(voting, 
                 optimize = 'MAE', 
                 choose_better = True,
                 n_iter = 30)

voting = finalize_model(voting)
sample = pd.read_csv('data/sample_submission.csv')
layer1_pred = voting.predict(test)
sample['num'] = layer1_pred
sample.to_csv('sub/pycaret.csv', index=False)
# Out:
# <style  type="text/css" >
# #T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col0,#T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col1,#T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col2,#T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col3,#T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col4,#T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow10_col5{
#             background:  yellow;
#         }</style><table id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col0" class="data row0 col0" >118.0355</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col1" class="data row0 col1" >30424.8401</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col2" class="data row0 col2" >174.4272</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col3" class="data row0 col3" >0.7321</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col4" class="data row0 col4" >0.3213</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow0_col5" class="data row0 col5" >0.2454</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col0" class="data row1 col0" >90.9710</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col1" class="data row1 col1" >18907.7571</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col2" class="data row1 col2" >137.5055</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col3" class="data row1 col3" >0.8504</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col4" class="data row1 col4" >0.3474</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow1_col5" class="data row1 col5" >0.2724</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col0" class="data row2 col0" >117.7045</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col1" class="data row2 col1" >35524.1198</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col2" class="data row2 col2" >188.4784</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col3" class="data row2 col3" >0.7652</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col4" class="data row2 col4" >0.3092</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow2_col5" class="data row2 col5" >0.2240</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col0" class="data row3 col0" >124.8754</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col1" class="data row3 col1" >36600.7186</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col2" class="data row3 col2" >191.3131</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col3" class="data row3 col3" >0.7467</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col4" class="data row3 col4" >0.4975</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow3_col5" class="data row3 col5" >0.4906</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col0" class="data row4 col0" >80.3365</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col1" class="data row4 col1" >10771.2451</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col2" class="data row4 col2" >103.7846</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col3" class="data row4 col3" >0.9017</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col4" class="data row4 col4" >0.4584</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow4_col5" class="data row4 col5" >0.4499</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col0" class="data row5 col0" >81.5603</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col1" class="data row5 col1" >12568.3130</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col2" class="data row5 col2" >112.1085</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col3" class="data row5 col3" >0.8822</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col4" class="data row5 col4" >0.3914</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow5_col5" class="data row5 col5" >0.3456</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col0" class="data row6 col0" >113.3352</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col1" class="data row6 col1" >31882.0418</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col2" class="data row6 col2" >178.5554</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col3" class="data row6 col3" >0.6871</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col4" class="data row6 col4" >0.2462</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow6_col5" class="data row6 col5" >0.1996</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col0" class="data row7 col0" >125.0179</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col1" class="data row7 col1" >44123.7726</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col2" class="data row7 col2" >210.0566</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col3" class="data row7 col3" >0.7959</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col4" class="data row7 col4" >0.2826</td>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow7_col5" class="data row7 col5" >0.2312</td>
#             </tr>
#             <tr>
#                         <th id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_493ea4ba_ed4f_11eb_a022_d8f8830f9b9arow8_col0" class
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eca5c8034f33> in <module>
#       7 voting = finalize_model(voting)
#       8 sample = pd.read_csv('data/sample_submission.csv')
# ----> 9 layer1_pred = voting.predict(X_test)
#      10 sample['num'] = layer1_pred
#      11 sample.to_csv('sub/pycaret.csv', index=False)
#
# NameError: name 'X_test' is not defined

# %%
sample = pd.read_csv('data/sample_submission.csv')
layer1_pred = voting.predict(test)
sample['num'] = layer1_pred
sample.to_csv('sub/pycaret0725.csv', index=False)

# %%
sample.head()
# Out:
#     code          num
# 0  C1072   538.432984
# 1  C1128  1191.874200
# 2  C1456   357.657555
# 3  C1840   412.945545
# 4  C1332  1028.327260

# %% [markdown]
# # Modeling with Gradient Boosting Regressor

# %% [markdown]
# - Setting Data For Model

# %%
X = train.drop(columns = ['target'])
y = train['target']

# %% [markdown]
# - Hyper params Tuning

# %%
def objective(trial: Trial) -> float:
    params_cat = {
        "random_state": 42,
        "learning_rate": 0.05,
        "n_estimators": 10000,
        "verbose" : 1,
        "objective" : "MAE",
        "max_depth": trial.suggest_int("max_depth", 1, 16),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.8, 1.0),
        "subsample": trial.suggest_float("subsample", 0.3, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "max_bin": trial.suggest_int("max_bin", 200, 500),
    }
    
    X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2)

    model = CatBoostRegressor(**params_cat)
    model.fit(
        X_tr,
        y_tr,
        eval_set=[(X_tr, y_tr), (X_val, y_val)],
        early_stopping_rounds=10,
        verbose=False,
    )

    cat_pred = model.predict(X_val)
    log_score = mean_absolute_error(y_val, cat_pred)
    
    return log_score

# %%
sampler = TPESampler(seed=42)
study = optuna.create_study(
    study_name="cat_opt",
    direction="minimize",
    sampler=sampler,
)
study.optimize(objective, n_trials=10)
print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# [I 2021-07-25 23:15:25,974] A new study created in memory with name: cat_opt
# [I 2021-07-25 23:15:26,172] Trial 0 finished with value: 110.84477884510203 and parameters: {'max_depth': 6, 'colsample_bylevel': 0.9901428612819833, 'subsample': 0.8123957592679836, 'min_child_samples': 62, 'max_bin': 246}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:26,313] Trial 1 finished with value: 142.13442465755838 and parameters: {'max_depth': 3, 'colsample_bylevel': 0.8116167224336399, 'subsample': 0.9063233020424546, 'min_child_samples': 62, 'max_bin': 413}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:26,433] Trial 2 finished with value: 117.94054482794724 and parameters: {'max_depth': 1, 'colsample_bylevel': 0.9939819704323989, 'subsample': 0.8827098485602951, 'min_child_samples': 25, 'max_bin': 254}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:26,606] Trial 3 finished with value: 129.472669872204 and parameters: {'max_depth': 3, 'colsample_bylevel': 0.8608484485919076, 'subsample': 0.6673295021425665, 'min_child_samples': 46, 'max_bin': 287}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:28,518] Trial 4 finished with value: 142.78428018892012 and parameters: {'max_depth': 10, 'colsample_bylevel': 0.8278987721304084, 'subsample': 0.5045012539746527, 'min_child_samples': 40, 'max_bin': 337}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:38,415] Trial 5 finished with value: 132.98154885876983 and parameters: {'max_depth': 13, 'colsample_bylevel': 0.8399347564316719, 'subsample': 0.6599641068895281, 'min_child_samples': 61, 'max_bin': 213}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:39,690] Trial 6 finished with value: 115.37034947782169 and parameters: {'max_depth': 10, 'colsample_bylevel': 0.8341048247374584, 'subsample': 0.3455361150896956, 'min_child_samples': 96, 'max_bin': 490}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:55,993] Trial 7 finished with value: 128.3645364048165 and parameters: {'max_depth': 13, 'colsample_bylevel': 0.8609227538346742, 'subsample': 0.3683704798044687, 'min_child_samples': 70, 'max_bin': 332}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:56,249] Trial 8 finished with value: 129.41605856362617 and parameters: {'max_depth': 2, 'colsample_bylevel': 0.8990353820222541, 'subsample': 0.32407196478065287, 'min_child_samples': 92, 'max_bin': 277}. Best is trial 0 with value: 110.84477884510203.
# [I 2021-07-25 23:15:58,805] Trial 9 finished with value: 152.9073781220833 and parameters: {'max_depth': 11, 'colsample_bylevel': 0.8623422152178822, 'subsample': 0.6640476148244676, 'min_child_samples': 57, 'max_bin': 255}. Best is trial 0 with value: 110.84477884510203.
# Best Score: 110.84477884510203
# Best trial: {'max_depth': 6, 'colsample_bylevel': 0.9901428612819833, 'subsample': 0.8123957592679836, 'min_child_samples': 62, 'max_bin': 246}

# %%
cat_p = study.best_trial.params
cat = CatBoostRegressor(**cat_p)

# %% [markdown]
# - StratifiedK-Fold for Regression

# %%
y_cat = pd.cut(y, 10, labels=range(10))
skf = StratifiedKFold(5)

preds = []
for tr_id, val_id in skf.split(X, y_cat) : 
    X_tr = X.iloc[tr_id]
    y_tr = y.iloc[tr_id]
    
    cat.fit(X_tr, y_tr, verbose = 0)
    
    pred = cat.predict(test)
    preds.append(pred)
cat_pred = np.mean(preds, axis = 0)

# %%
sample = pd.read_csv('data/sample_submission.csv')
sample['num'] = cat_pred
sample.to_csv('sub/cat0725.csv', index=False)

# %%
sample
# Out:
#       code          num
# 0    C1072   719.764596
# 1    C1128  1242.199280
# 2    C1456   512.562147
# 3    C1840   522.613099
# 4    C1332  1160.056303
# ..     ...          ...
# 145  C2456   212.657474
# 146  C1266   423.476127
# 147  C2152   132.666548
# 148  C1267   356.777158
# 149  C2189   154.568354
#
# [150 rows x 2 columns]

# %%
sample
# Out:
#       code          num
# 0    C1072   755.096127
# 1    C1128  1152.608154
# 2    C1456   501.174457
# 3    C1840   510.433067
# 4    C1332  1051.004018
# ..     ...          ...
# 145  C2456   239.699284
# 146  C1266   457.090515
# 147  C2152   101.255046
# 148  C1267   339.011868
# 149  C2189   -58.779950
#
# [150 rows x 2 columns]
